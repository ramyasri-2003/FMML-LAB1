# %% [markdown]
# <a href="https://colab.research.google.com/github/ramyasri-2003/FMML-ASSIGNMENTS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 20:15:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   117MB/s    in 0.6s
#
# 2024-03-27 20:15:23 (117 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21874   1403.4206v1  We present a nonparametric prior over reversib...  stat
# 37918   1111.1802v5  We develop a Bayesian nonparametric approach t...  stat
# 11283  1507.02801v2  A mixture of factor analyzers is a semi-parame...  stat
# 31026  1802.01722v1  Light field imaging is limited in its computat...    cs
# 35716   1110.2767v1  Allocating scarce resources among agents to ma...    cs
# ...             ...                                                ...   ...
# 30530  1712.04711v1  Convolution Neural Networks, known as ConvNets...    cs
# 17085  1708.04765v1  Dialog act identification plays an important r...    cs
# 22072   1410.0860v1  In recent years rank aggregation has received ...  stat
# 21100  1707.08817v1  We propose a general and model-free approach f...    cs
# 22625  1703.01872v2  Inspired by the importance of diversity in bio...  stat
#
#                                                    title  year  \
# 21874  A reversible infinite HMM using normalised ran...  2014
# 37918  Combinatorial clustering and the beta negative...  2011
# 11283              Adaptive Mixtures of Factor Analyzers  2015
# 31026  Compressive Light Field Reconstructions using ...  2018
# 35716  Resource Allocation Among Agents with MDP-Indu...  2011
# ...                                                  ...   ...
# 30530  Regularization and Optimization strategies in ...  2017
# 17085  Dialogue Act Segmentation for Vietnamese Human...  2017
# 22072  Individualized Rank Aggregation using Nuclear ...  2014
# 21100  Leveraging Demonstrations for Deep Reinforceme...  2017
# 22625  Computational Eco-Systems for Handwritten Digi...  2017
#
#                                                 keywords
# 21874  [nonparametric, reversible, completely, specif...
# 37918  [nonparametric, individuals, simultaneously, e...
# 11283  [analyzers, parametric, estimator, generalizes...
# 31026  [computational, processing, dimensions, sacrif...
# 35716  [allocating, resources, computationally, chall...
# ...                                                  ...
# 30530  [convolution, exceptionally, architecture, par...
# 17085  [identification, important, understanding, con...
# 22072  [aggregation, significant, attention, communit...
# 21100  [reinforcement, deterministic, algorithm, demo...
# 22625  [importance, diversity, biological, heterogene...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21874    [nonparametric, reversible, completely, specif...
# 37918    [nonparametric, individuals, simultaneously, e...
# 11283    [analyzers, parametric, estimator, generalizes...
# 31026    [computational, processing, dimensions, sacrif...
# 35716    [allocating, resources, computationally, chall...
#                                ...
# 20236    [taxonomic, represent, similarity, considered,...
# 9425     [disasters, catastrophic, functionality, infra...
# 8321     [clustering, clustering, approaches, capabilit...
# 40229    [understanding, particular, annotated, differe...
# 39871    [convolutional, segmentation, different, archi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8928 words.
# Out of those 4591 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="710b9985-9d2a-41c3-85c6-1ca3c800548b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("710b9985-9d2a-41c3-85c6-1ca3c800548b")) {                    Plotly.newPlot(                        "710b9985-9d2a-41c3-85c6-1ca3c800548b",                        [{"x":["dirichlet","countably","normalised","specifically","nonparametric","reversible","reinforcement","predictive","undirected","resulting","constructing","completely","explicitly","alternative","distribution","properties","recording","construct","characterised","reversibility","processes","transition","efficient","hierarchical","straightforward","enforcing","inference","segmentation","experiments","characterize","recognition","introduce","posterior","exhibited","conjugate","algorithms","clustering","individuals","individual","appropriate","extension","combinatorial","asymptotic","stochastic","dimensional","parameter","simultaneously","benchmarks","different","algorithm","component","gaussians","nonlinear","parametric","conditional","selection","dimensionality","reduction","permitting","generalizes","effectiveness","parsimonious","estimator","automatic","represented","complexity","simultaneous","measurements","dimensions","solutions","viewpoints","combination","simulated","sacrifice","typically","dictionary","computational","achieving","acquisition","decreases","multiplexing","decreased","processing","synthetic","compressive","resolution","performed","iterative","potential","particular","autoencoder","architecture","recovered","consisting","reconstruction","significantly","reconstructions","equivalent","demonstrate","interested","resources","technique","optimization","empirically","challenging","computationally","allocation","environments","realizable","representing","allocating","reductions","preferences","exponentially","utilities","optimally","containing","illustrations","projection","computation","direction","dimension","generalize","evaluations","principal","sensitive","engineering","calculation","components","asymptotically","estimation","calculate","subspaces","calculated","performing","phonological","transcribed","performance","significant","important","sequences","variations","challenges","dependent","classifiers","technical","approaches","investigate","segmental","available","realistic","independent","adaptation","accuracies","recognize","classical","developed","uncontrolled","linearized","promising","statistical","decomposition","principle","sociology","framework","environment","multimedia","statistics","crowdsourcing","iteration","consistency","established","supported","approximations","experienced","detection","renaissance","comparison","faithfully","formulates","instances","weighting","generally","perceptrons","multilayer","methodology","filtering","continuous","identifying","measuring","detrimental","considered","backpropagation","individually","beneficial","classification","initially","especially","explanation","techniques"],"y":[24,1,1,186,23,5,115,55,9,148,45,30,69,92,225,210,5,81,5,2,101,41,429,109,21,10,193,219,607,43,385,343,47,4,11,594,141,35,116,74,75,37,12,129,163,100,111,87,741,817,106,8,60,35,93,182,49,103,3,35,186,2,32,207,86,227,35,53,44,148,13,121,59,3,84,47,275,79,37,13,2,6,271,131,18,101,140,78,145,264,27,214,15,46,106,280,6,56,555,26,75,243,317,70,235,104,26,68,1,77,3,11,36,21,5,24,47,0,51,151,60,53,42,43,37,56,60,15,111,12,204,29,12,30,80,4,4,877,241,357,96,62,114,73,121,38,462,139,2,294,66,135,55,25,46,92,190,3,2,109,140,76,63,1,545,110,12,64,15,63,42,54,20,28,7,357,2,152,4,5,95,25,64,6,12,66,66,100,78,29,3,139,20,10,26,498,23,107,15,373],"type":"bar"},{"x":["dirichlet","countably","normalised","specifically","nonparametric","reversible"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4591,), (4591, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>Monolingual</span> <span style=''>Corpora</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.824);'>Translation</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>for</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.824);'>translation</span> <span style=''>has</span> <span style=''>shown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>promising</span> <span style=''>results</span> <span style=''>for</span> <span style=''>En</span> <span style=''>Fr</span> <span style=''>and</span> <span style=''>En</span> <span style=''>De</span> <span style='background-color:rgba(0, 255, 0, 0.824);'>translation</span> <span style=''>Arguably</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style=''>factors</span> <span style=''>behind</span> <span style=''>this</span> <span style=''>success</span> <span style=''>has</span> <span style=''>been</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>availability</span> <span style=''>of</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>parallel</span> <span style=''>corpora</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>how</span> <span style=''>to</span> <span style=''>leverage</span> <span style=''>abundant</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>monolingual</span> <span style=''>corpora</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.824);'>translation</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>a</span> <span style=''>phrase</span> <span style=''>based</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>baseline</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>up</span> <span style=''>to</span> <span style=''>196</span> <span style=''>BLEU</span> <span style='background-color:rgba(0, 255, 0, 0.3177570093457944);'>improvement</span> <span style=''>on</span> <span style=''>the</span> <span style=''>low</span> <span style=''>resource</span> <span style=''>language</span> <span style=''>pair</span> <span style=''>Turkish</span> <span style=''>English</span> <span style=''>and</span> <span style=''>159</span> <span style=''>BLEU</span> <span style=''>on</span> <span style=''>the</span> <span style=''>focused</span> <span style=''>domain</span> <span style=''>task</span> <span style=''>of</span> <span style=''>Chinese</span> <span style=''>English</span> <span style=''>chat</span> <span style=''>messages</span> <span style=''>While</span> <span style=''>our</span> <span style=''>method</span> <span style=''>was</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419356);'>initially</span> <span style=''>targeted</span> <span style=''>toward</span> <span style=''>such</span> <span style=''>tasks</span> <span style=''>with</span> <span style=''>less</span> <span style=''>parallel</span> <span style=''>data</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>also</span> <span style=''>extends</span> <span style=''>to</span> <span style=''>hig ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>and</span> <span style=''>Parallel</span> <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Effective</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>required</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>stored</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>on</span> <span style=''>one</span> <span style=''>machine</span> <span style=''>Another</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>one</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encounter</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>contaminations</span> <span style=''>that</span> <span style=''>damage</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>The</span> <span style=''>parallel</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>strategy</span> <span style=''>divides</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>data</span> <span style=''>set</span> <span style=''>into</span> <span style=''>roughly</span> <span style=''>equal</span> <span style=''>subsets</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>After</span> <span style=''>local</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>or</span> <span style=''>other</span> <span style=''>modelvariable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>final</span> <span style=''>model</span> <span style=''>by</span> <span style=''>using ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>BPR</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Personalized</span> <span style=''>Ranking</span> <span style=''>from</span> <span style=''>Implicit</span> <span style=''>Feedback</span> <br/><br/><span style=''>Item</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>is</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>personalized</span> <span style=''>ranking</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>items</span> <span style=''>(eg</span> <span style=''>websites</span> <span style=''>movies</span> <span style=''>products)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>most</span> <span style=''>common</span> <span style=''>scenario</span> <span style=''>with</span> <span style=''>implicit</span> <span style=''>feedback</span> <span style=''>(eg</span> <span style=''>clicks</span> <span style=''>purchases)</span> <span style=''>There</span> <span style=''>are</span> <span style=''>many</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>item</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>from</span> <span style=''>implicit</span> <span style=''>feedback</span> <span style=''>like</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3898305084745763);'>factorization</span> <span style=''>(MF)</span> <span style=''>or</span> <span style=''>adaptive</span> <span style=''>knearest</span> <span style=''>neighbor</span> <span style=''>(kNN)</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>item</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>personalized</span> <span style=''>ranking</span> <span style=''>none</span> <span style=''>of</span> <span style=''>them</span> <span style=''>is</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>for</span> <span style=''>ranking</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>BPR</span> <span style=''>Opt</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>personalized</span> <span style=''>ranking</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5458937198067634);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.6097560975609757);'>estimator</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorit ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>on</span> <span style=''>Graphs</span> <span style=''>by</span> <span style=''>Learning</span> <span style=''>Aligned</span> <span style=''>Graph</span> <span style=''>Bases</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>Given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>label</span> <span style=''>function</span> <span style=''>on</span> <span style=''>a</span> <span style=''>source</span> <span style=''>graph</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transferring</span> <span style=''>the</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style=''>the</span> <span style=''>source</span> <span style=''>graph</span> <span style=''>to</span> <span style=''>a</span> <span style=''>target</span> <span style=''>graph</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>target</span> <span style=''>label</span> <span style=''>function</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>about</span> <span style=''>the</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>the</span> <span style=''>two</span> <span style=''>domains</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>content</span> <span style=''>of</span> <span style=''>the</span> <span style=''>label</span> <span style=''>function</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>signal</span> <span style=''>has</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>over</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>the</span> <span style=''>target</span> <span style=''>graphs</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>coherent</span> <span style=''>bases</span> <span style=''>on</span> <span style=''>the</span> <span style=''>two</span> <span style=''>graphs</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style=''>graph</span> <span style=''>basis</span> <span style=''>vectors</span> <span style=''>have</span> <span style=''>similar</span> <span style=''>spectral</span> <span style=''>content</span> <span style=''>while</span> <span style=''>aligning</span> <span style=''>the</span> <span style=''>two</span> <span style=''>graphs</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style='backgr ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="12805168-4e63-4c35-a4a6-0c0deb8a1cd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12805168-4e63-4c35-a4a6-0c0deb8a1cd8")) {                    Plotly.newPlot(                        "12805168-4e63-4c35-a4a6-0c0deb8a1cd8",                        [{"x":["dirichlet","countably","normalised","specifically","nonparametric","reversible","reinforcement","predictive","undirected","resulting","constructing","completely","explicitly","alternative","distribution","properties","recording","construct","characterised","reversibility","processes","transition","efficient","hierarchical","straightforward","enforcing","inference","segmentation","experiments","characterize","recognition","introduce","posterior","exhibited","conjugate","algorithms","clustering","individuals","individual","appropriate","extension","combinatorial","asymptotic","stochastic","dimensional","parameter","simultaneously","benchmarks","different","algorithm","component","gaussians","nonlinear","parametric","conditional","selection","dimensionality","reduction","permitting","generalizes","effectiveness","parsimonious","estimator","automatic","represented","complexity","simultaneous","measurements","dimensions","solutions","viewpoints","combination","simulated","sacrifice","typically","dictionary","computational","achieving","acquisition","decreases","multiplexing","decreased","processing","synthetic","compressive","resolution","performed","iterative","potential","particular","autoencoder","architecture","recovered","consisting","reconstruction","significantly","reconstructions","equivalent","demonstrate","interested","resources","technique","optimization","empirically","challenging","computationally","allocation","environments","realizable","representing","allocating","reductions","preferences","exponentially","utilities","optimally","containing","illustrations","projection","computation","direction","dimension","generalize","evaluations","principal","sensitive","engineering","calculation","components","asymptotically","estimation","calculate","subspaces","calculated","performing","phonological","transcribed","performance","significant","important","sequences","variations","challenges","dependent","classifiers","technical","approaches","investigate","segmental","available","realistic","independent","adaptation","accuracies","recognize","classical","developed","uncontrolled","linearized","promising","statistical","decomposition","principle","sociology","framework","environment","multimedia","statistics","crowdsourcing","iteration","consistency","established","supported","approximations","experienced","detection","renaissance","comparison","faithfully","formulates","instances","weighting","generally","perceptrons","multilayer","methodology","filtering","continuous","identifying","measuring","detrimental","considered","backpropagation","individually","beneficial","classification","initially","especially","explanation","techniques","parameters","simplicity","understand","theoretically","deconvnet","generalization","patternnet","explanations","thresholds","stability","estimating","benchmark","regression","laboratory","accurately","penetration","prediction","validated","reliability","indicates","renewable","superiority","parallelized","completion","guarantees","conditions","programming","assumptions","including","numerical","decompositions","minimization","recovering","decomposed","identification","graphical","applications","observation","probabilities","expectation","consistently","underlies","construction","objective","transforms","strategies","generality","outperforms","experimental","considerable","constructions","providing","structure","estimates","converting"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	illustrations
# 	statistician
# 	nonparametrically
# 	spectrogram
# 	composers
# 	procrustes
# 	spectroscopy
# 	heteroscedasticity
# 	volatility
# 	sparsistency
# 	attrition
# 	penalised
# 	emphsparse
# 	renormalization
# 	coregionalization
# 	circumvents
# 	overdetermined
# 	semiparametric
# 	informally
# 	covariances
# Some words which never appear in Statistics papers:
# 	multiplexing
# 	phonological
# 	transcribed
# 	insertion
# 	quadcopter
# 	kinematic
# 	progressed
# 	ontological
# 	consumptions
# 	neglected
# 	generations
# 	genotypes
# 	haphazard
# 	employment
# 	broadcast
# 	installation
# 	authoring
# 	mutations
# 	communicating
# 	newspapers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069273502961849e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
